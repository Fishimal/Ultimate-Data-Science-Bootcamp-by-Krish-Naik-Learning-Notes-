# %% [markdown]
# # Python-2
# ## Agenda:
#  - String Properties
#  - Operators - II
#  - Control Flow
#  - Control Flow - II (advance)
#  - Non-primitive Data Types

# %% [markdown]
# ### String Operations

# %%
print(type(1))
# Out:
# <class 'int'>

# %%
print(type("Data"))
# Out:
# <class 'str'>

# %%
"    Data Science    ".strip() # strip is a property of str
# Out:
# 'Data Science'

# %%
1.strip()
# Out:
#   Cell In[6], line 1
#     1.strip()
#      ^
# SyntaxError: invalid decimal literal

# %%
"1".strip() # strip() --> is a methid, it does something only for its own data type
# Out:
# '1'

# %%
a = 2
id(a) # id() --> is a function, it does something
# Out:
# 4372308536

# %%
a.id()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a.id()
#
# AttributeError: 'int' object has no attribute 'id'

# %%
dir(a)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %%
name = "Rubina D    "

# %%
# strip()
name = name.strip() # removes all spaces from right and left side of the string
print(name)
# Out:
# Rubina D

# %%
# rstrip()
name = "    Rubina D    "
print(name.rstrip())
# Out:
#     Rubina D

# %%
# lstrip()
name = "    Rubina D    "
print(name.lstrip())
# Out:
# Rubina D

# %%
# remove space from the string without using strip()
name = "    Rubina D    "
name = name.lstrip()
name = name.rstrip()
name
# Out:
# 'Rubina D'

# %%
name = "    Rubina D    "
name = name.lstrip().rstrip()
name
# Out:
# 'Rubina D'

# %% [markdown]
# ### Operators - II

# %% [markdown]
# #### Relational Operators

# %%
a = 100
b = 200

# %%
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
print(a == b)
print(a != b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
a = "Data"
b = "Data "

print(a == b)
# Out:
# False

# %%
user_id = 123
password = "helloworld"

print(user_id == 100)
print(password == "krishnaikacademy")
# Out:
# False
# False

# %%
age_threshold = 18

person_1_age = 16

print(person_1_age >= age_threshold)
# Out:
# False

# %% [markdown]
# #### Assignment Operator

# %%
a = 2

# %%
a += 1 # a = a + 1
print(a)
# Out:
# 3

# %%
a -= 1 # a = a - 1
print(a)
# Out:
# 2

# %%
a *= 2 # a = a + 2
print(a)
# Out:
# 4

# %%
a /= 2 # a = a / 2
print(a)
# Out:
# 2.0

# %%
a //= 2 # a = a // 2
print(a)
# Out:
# 1.0

# %% [markdown]
# #### Logical Operator

# %%
bool_a = True
bool_b = False

# %%
bool_a and bool_b
# Out:
# False

# %%
bool_a or bool_b
# Out:
# True

# %%
not bool_a
# Out:
# False

# %%
not bool_b
# Out:
# True

# %%
# Club Entry Conditions
# Person should be over 18
# Person should have at least 500 INR to enter in club

# %%
person_1_age = 20
person_threshold = 18

min_balance = 500
person_1_balance = 100

print((person_1_age >= person_threshold) and (person_1_balance >= min_balance))
# Out:
# False

# %%
person_2_age = 20

person_2_balance = 600

print((person_2_age >= person_threshold) and (person_2_balance >= min_balance))
# Out:
# True

# %% [markdown]
# #### Bitwise Operator

# %%
a = 3
b = 1

print(a & b)
# Out:
# 1

# %%
print(a | b)
# Out:
# 3

# %%
print(~a) # considers the sign also a bit hence, the output is in negative
# Out:
# -4

# %%
print(a ^ b)
# Out:
# 2

# %%
print(a << b)
# Out:
# 6

# %%
print(a >> b)
# Out:
# 1

# %%
bin(30) # bin to decimal
# Out:
# '0b11110'

# %%
hex(30) # hexadecimal to decimal
# Out:
# '0x1e'

# %% [markdown]
# ### Conditional Statements or Control Flow

# %%
# we want to give access to batch 1 recording to people who buy batch 2

current_batch = 2

if current_batch == 2:
    print("Access to UDS batch 1.0 is also provided")
else:
    print("You only have access to UDS batch 1.0")
# Out:
# Access to UDS batch 1.0 is also provided

# %%
current_batch = 3

if current_batch == 2:
    print("Access to UDS batch 1.0 is also provided")
else:
    print("You only have access to UDS batch 1.0")
# Out:
# You only have access to UDS batch 1.0

# %%
current_batch = 3

if current_batch == 2:
    print("Access to UDS batch 1.0 is also provided")

a = 2
b = 2
print(a + b)
# Out:
# 4

# %%
else:
    print("Access to UDS batch 1.0 is also provided")

a = 2
b = 2
print(a + b)
# Out:
#   Cell In[26], line 1
#     else:
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Control Flow - II

# %% [markdown]
# #### if-elif-else

# %%
operation_name = "data"

if operation_name == "add":
    print("Perform Addidtion")
elif operation_name == "subtract":
    print("Perform Subtraction")
else:
    print("No selected operation name found.")
# Out:
# No selected operation name found.

# %%
operation_name = "divide"

# control flow start
if operation_name == "add":
    print("Perform Addidtion")
elif operation_name == "subtract":
    print("Perform Subtraction")
elif operation_name == "divide":
    print("Perform Division")
else:
    print("No selected operation name found.")
# control flow end

print("Program Ended")
# Out:
# Perform Division
# Program Ended

# %%
operation_name = "divide"

# control flow start
if operation_name == "add":
    print("Perform Addidtion")
# control flow end

# control flow start
if operation_name == "subtract":
    print("Perform Subtraction")
elif operation_name == "divide":
    print("Perform Division")
else:
    print("No selected operation name found.")
# control flow end
# Out:
# Perform Division

# %%
operation_name = "add"

# control flow start
if operation_name == "add":
    print("Perform Addidtion")
# control flow end

# control flow start
if operation_name == "subtract":
    print("Perform Subtraction")
elif operation_name == "divide":
    print("Perform Division")
else:
    print("No selected operation name found.")
# control flow end
# Out:
# Perform Addidtion
# No selected operation name found.

# %%
operation_name = "add"

# control flow start
if operation_name == "add":
    print("Perform Addidtion")
# control flow end

# control flow start
if operation_name == "add":
    print("Perform Addidtion")
elif operation_name == "subtract":
    print("Perform Subtraction")
elif operation_name == "divide":
    print("Perform Division")
else:
    print("No selected operation name found.")
# control flow end
# Out:
# Perform Addidtion
# Perform Addidtion

# %%
operation_name = "add"

# control flow start
if operation_name == "add":
    print("Perform Addidtion")
elif operation_name == "add":
    print("Perform Addidtion")
elif operation_name == "subtract":
    print("Perform Subtraction")
elif operation_name == "divide":
    print("Perform Division")
else:
    print("No selected operation name found.")
# control flow end
# Out:
# Perform Addidtion

# %%
age = 19
batch = 2.0
session_number = 4

# control flow start
if age > 19:
    print("19")
# control flow end

# control flow start
if batch > 1.0:
    print("give access to v1.0")
# control flow end

# control flow start
if session_number > 1:
    print("Induction Class Ended")
# control flow end
# Out:
# give access to v1.0
# Induction Class Ended

# %% [markdown]
# ### Non-Primitive Data Types

# %% [markdown]
# #### Lists

# %%
id_people = [100, 101, 102, 103, 104, 105]

# %%
print(id_people)
# Out:
# [100, 101, 102, 103, 104, 105]

# %%
print(*id_people)
# Out:
# 100 101 102 103 104 105

# %%
people = [100, 101, 102, "A", "b", 37.4, True]

# %%
print(people)
# Out:
# [100, 101, 102, 'A', 'b', 37.4, True]

# %%
print(type(people))
# Out:
# <class 'list'>

# %%
people.append("Data Science")

# %%
print(people)
# Out:
# [100, 101, 102, 'A', 'b', 37.4, True, 'Data Science']

# %%
register = []
print(type(register))
# Out:
# <class 'list'>

# %%
register.append(["Rubina", 101, "+91-1234567890", "visit"])

# %%
# entry_1 = ["Rubina", 101, "+91-1234567890", "visit"]
# register.append(entry_1)

# %%
print(register)
# Out:
# [['Rubina', 101, '+91-1234567890', 'visit']]

# %%
register.append(["Dhaval", 101, "+91-0123456789", "visit"])
# append is a method of class list

# %%
print(register)
# Out:
# [['Rubina', 101, '+91-1234567890', 'visit'], ['Dhaval', 101, '+91-0123456789', 'visit']]

# %%
len(register) # function
# Out:
# 2

# %%
len(register[0])
# Out:
# 4
