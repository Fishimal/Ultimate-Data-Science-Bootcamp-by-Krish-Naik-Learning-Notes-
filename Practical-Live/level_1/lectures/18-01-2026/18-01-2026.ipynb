# %% [markdown]
# # Python - 2
#
# ## Agenda:
# - String properties
# - Operators - II
# - Control flow
# - Control flow - II (advance)
# - Non-primitive data type

# %% [markdown]
# ### String operations

# %%
name = "Rubina D   "

# %%
# strip()
name = name.strip() # it removes spaces from right and left side of the string
name

# %%
# rstrip()
name = "   Rubina D   "
# print(name.rstrip())
name.rstrip()

# %%
# lstrip()
name = "   Rubina D   "
name.lstrip()

# %%
# remove space from both side without using strip()
name = "   Rubina D   "
name = name.lstrip()
name = name.rstrip()
name

# %%
name = "   Rubina D   "
name = name.lstrip().rstrip()
name

# %%
name = "   Rubina D   "
name = name.rstrip().lstrip()
name

# %% [markdown]
# ### Operators - II

# %% [markdown]
# #### Relational operators or Comparison operators

# %%
a = 100
b = 200

# %%
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
print(a == b)
print(a != b)

# %%
a = "Data"
b = "Data "

print(a == b)

# %%
id_ = 123
password = "helloworld"

print(id_ == 100)
print(password == 'krishnaikacademy')

# %%
age_threshold = 18

person_1_age = 18

print(person_1_age >= age_threshold)

# %% [markdown]
# #### Assignment operator

# %%
a = 2
print(a)

# %%
a += 1 # a = a+1
print(a)

# %%
a -= 1 # a = a-1
print(a)

# %%
a *= 2 # a = a*2
print(a)

# %%
a /= 2 # a = a/2
print(a)

# %%
a / 0.3

# %%
a //= 0.3 # a = a//2
print(a)

# %% [markdown]
# #### Logical Operators

# %%
bool_a = True
bool_b = False

# %%
bool_a and bool_b

# %%
bool_a or bool_b

# %%
not bool_b

# %%
not bool_a

# %%
# Club entry conditions
# - person should be over 18 or equal
# - person should have atleast 500 INR to enter in club

person_age = 20
person_threshold = 18

min_balance = 500
person_balance = 600

print((person_age >= person_threshold) and (person_balance >= min_balance))

# %%
person_age = 20
person_threshold = 18

min_balance = 500
person_balance = 100

print((person_age >= person_threshold) and (person_balance >= min_balance))

# %% [markdown]
# #### Bitwise operators

# %%
a = 3
b = 1

print(a & b)

# %%
print(a | b)

# %%
print(~a) # ~ -> considers the sign as a bit hence the o/p is in (-)ve

# %%
print(a ^ b)

# %%
print(a << 1)

# %%
print(a >> 1)

# %%
a = 30
bin(a)

# %%
hex(a)

# %% [markdown]
# ### Conditional Statements or Control flow

# %%
# we want to give access to batch 1 recording to people who buy batch 2

current_batch = 3

if current_batch==2:
    print("Access to UDS batch 1.0 also provided")
else:
    print("You only have access to UDS batch 1.0")

# %%
current_batch = 2

if current_batch==2:
    print("Access to UDS batch 1.0 also provided")
else:
    print("You only have access to UDS batch 1.0")

# %%
# we want to give access to batch 1 recording to people who buy batch 2

current_batch = 3

if current_batch==2:
    print("Access to UDS batch 1.0 also provided")

a = 2
b = 2
print(a+b)

# %%
# we want to give access to batch 1 recording to people who buy batch 2

current_batch = 3

if current_batch == 2:
    print("hello")
else:
    print("You only have access to UDS batch 1.0")

a = 2
b = 2
print(a+b)

# %%
if True:
    print("hello")

# %% [markdown]
# ### if-elif-else

# %%
operation_name = "divide"

# contorl flow start
if operation_name == "add":
    print("Perform addition")
elif operation_name == "subtract":
    print("Perform subtraction")
elif operation_name == "divide":
    print("Perform division")
else:
    print("No selected operation name found.")
# contorl flow end

# %%
operation_name = "add"

# contorl flow start
if operation_name == "add":
    print("Perform addition")
# contorl flow end

# contorl flow start
if operation_name == "substract":
    print("Perform substraction")
elif operation_name == "divide":
    print("Perform division")
else:
    print("No selected operation name found.")
# contorl flow end

# %%
operation_name = "add"

# contorl flow start
if operation_name == "add":
    print("Perform addition")
# contorl flow end

# contorl flow start
if operation_name == "add":
    print("Perform addition")
elif operation_name == "substract":
    print("Perform substraction")
elif operation_name == "divide":
    print("Perform division")
else:
    print("No selected operation name found.")
# contorl flow end

# %%
age = 19
batch = 2.0
session_number = 4

# contorl flow start
if age > 19:
    print("19")
# contorl flow end

# contorl flow start
if batch > 1.0:
    print("gives access to v1.0")
# contorl flow end

# contorl flow start
if session_number > 1:
    print("Induction class ended")
# contorl flow end

# %% [markdown]
# ### Non-primitive Data Types

# %% [markdown]
# #### Lists

# %%
id_people = [100, 101, 102, 103, 104, 105]

# %%
print(id_people)

# %%
print(*id_people)

# %%
people = [101, 100, 102, "A", "b", 37.4, True]

# %%
print(people)

# %%
print(type(people))

# %%
people.append("Data science")

# %%
print(people)

# %%
register = []
print(type(register))

# %%
register.append(["Rubina", 101, "+911234567890", "visit"])

# %%
# a = ["monal", 101, "+911234567890", "visit"]
# register.append(a)

# %%
print(register)

# %%
register.append(["Dhaval", 500, "+919234567890", "visit"])

# %%
print(register)

# %% [markdown]
# ### experimentation on list

# %%
dummy = []

# %%
print(dummy)

# %%
dummy.append([1,2,3,4,"hello", "Rubina", 101]) 
# append is a method of list

# %%
len(dummy) # function

# %%
len(dummy[0])
