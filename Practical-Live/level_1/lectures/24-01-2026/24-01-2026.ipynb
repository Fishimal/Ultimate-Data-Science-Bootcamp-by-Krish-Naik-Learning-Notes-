# %% [markdown]
# # Python - 4
#
# ## Agenda:
# - Discussion on Resource
# - Non-Primitive Data Types
# - while Loops
# - Functions
# - Function Arguments

# %% [markdown]
# ### Non-Primitive Data Types

# %% [markdown]
# #### 1. Lists

# %%
l = ["Hello", "Hey", "Python", 10, False]

# %% [markdown]
# ##### Accessing list elements/values

# %%
print(l[3]) # +(ve) indexing from left to right
# Out:
# 10

# %%
print(l[2])
# Out:
# Python

# %%
print(l[0])
# Out:
# Hello

# %%
print(l[-1]) # -(ve) indexing from right to left
# Out:
# False

# %%
print(l[-2])
# Out:
# 10

# %% [markdown]
# ##### Finding total elements in a list

# %%
len("Data")
# Out:
# 4

# %%
len(l)
# Out:
# 5

# %%
# len(l) --> 5
l[len(l)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # len(l) --> 5
# ----> 2 l[len(l)]
#
# IndexError: list index out of range

# %%
l[len(l) - 1] # len(l)- 1 --> 5 - 1 --> 4 --> l[4] --> False
# Out:
# False

# %%
l[-5]
# Out:
# 'Hello'

# %%
l[-6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 l[-6]
#
# IndexError: list index out of range

# %% [markdown]
# ##### Deleting elements from a list

# %%
l
# Out:
# ['Hello', 'Hey', 'Python', 10, False]

# %%
l.pop() # by-default pop() considers the last element of the list
# Out:
# False

# %%
l
# Out:
# ['Hello', 'Hey', 'Python', 10]

# %%
l.append(True)

# %%
l
# Out:
# ['Hello', 'Hey', 'Python', 10, True]

# %%
l.pop(0) # we can also specify the index in pop()
# Out:
# 'Hello'

# %%
l
# Out:
# ['Hey', 'Python', 10, True]

# %%
l.append("Hey")

# %%
l
# Out:
# ['Hey', 'Python', 10, True, 'Hey']

# %%
# how to remove an element from the list, when we don't know the index but 
# we know the value

# we will use remove() -> it only removes the 1st occurrence

l.remove("Hey")

# %%
l
# Out:
# ['Python', 10, True, 'Hey']

# %%
l.remove("Hey")

# %%
l
# Out:
# ['Python', 10, True]

# %% [markdown]
# ##### Adding elements into a list in a specific index

# %%
l.insert(2, "Machine learning")

# %%
l
# Out:
# ['Python', 10, 'Machine learning', True]

# %%
l[0] = "Python-v2.0"

# %%
l
# Out:
# ['Python-v2.0', 10, 'Machine learning', True]

# %% [markdown]
# #### 2. Dictionary

# %%
# {key : value}
# register = {
#     "Rohit" : ["12-12-1980", 123456789, "abcdefgh"],
#     "Rohit" : ["12-12-1980", 123456789, "abcd"]
# }

# %%
print(register)
# Out:
# {'Rohit': ['12-12-1980', 123456789, 'abcd']}

# %%
register = {
    "Rohit" : ["12-12-1980", 123456789, "abcdefgh"],
    "Rohith" : ["12-12-1980", 123456789, "abcd"],
    "Rubina" : False
}

# %%
print(register)
# Out:
# {'Rohit': ['12-12-1980', 123456789, 'abcdefgh'], 'Rohith': ['12-12-1980', 123456789, 'abcd'], 'Rubina': False}

# %%
government_sys = {
    101 : ["Rubina"],
    102 : ["Dhaval"],
    103 : ["Saumya"],
    104 : ["Sangeetha"]
}

# %%
print(government_sys)
# Out:
# {101: ['Rubina'], 102: ['Dhaval'], 103: ['Saumya'], 104: ['Sangeetha']}

# %%
government_sys.get(101)
# Out:
# ['Rubina']

# %%
government_sys.get(102, "Value not present")
# Out:
# ['Dhaval']

# %%
government_sys[103]
# Out:
# ['Saumya']

# %%
government_sys[106]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 government_sys[106]
#
# KeyError: 106

# %%
government_sys.get(106, "Value not present")
# Out:
# 'Value not present'

# %%
government_sys.keys()
# Out:
# dict_keys([101, 102, 103, 104])

# %%
government_sys.values()
# Out:
# dict_values([['Rubina'], ['Dhaval'], ['Saumya'], ['Sangeetha']])

# %%
print(list(government_sys.keys()))
# Out:
# [101, 102, 103, 104]

# %%
print(list(government_sys.values()))
# Out:
# [['Rubina'], ['Dhaval'], ['Saumya'], ['Sangeetha']]

# %%
for key in list(government_sys.keys()):
    print(key)
# Out:
# 101
# 102
# 103
# 104

# %%
for value in list(government_sys.values()):
    print(value)
# Out:
# ['Rubina']
# ['Dhaval']
# ['Saumya']
# ['Sangeetha']

# %%
for key in government_sys.keys():
    print(key)
# Out:
# 101
# 102
# 103
# 104

# %%
for value in government_sys.values():
    print(value)
# Out:
# ['Rubina']
# ['Dhaval']
# ['Saumya']
# ['Sangeetha']

# %%
a = {
    [1, 2, 3] : "Hello"
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 a = {
#       2     [1, 2, 3] : "Hello"
#       3 }
#
# TypeError: unhashable type: 'list'

# %%
for key, value in government_sys.items():
    print(f"{value[0]}'s ID is {key}")
# Out:
# Rubina's ID is 101
# Dhaval's ID is 102
# Saumya's ID is 103
# Sangeetha's ID is 104

# %% [markdown]
# #### 3. Tuples

# %%
dob = (10, "March", 1920)

# %%
type(dob)
# Out:
# tuple

# %%
print(type(dob))
# Out:
# <class 'tuple'>

# %%
dob[0]
# Out:
# 10

# %%
dob[0] = 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 dob[0] = 20
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(dob)
# Out:
# (10, 'March', 1920)

# %%
register_v2 = {
    101 : {
        "Name" : "Rubina",
        "DOB" : (1, "Jan", 1980),
        "Phone No." : "+91-45798976540"
    },
    102 : {
        "Name" : "Dhaval",
        "DOB" : (29, "Feb", 1980),
        "Phone No." : "+91-42398976540"
    }
}

# %%
register_v2
# Out:
# {101: {'Name': 'Rubina',
#   'DOB': (1, 'Jan', 1980),
#   'Phone No.': '+91-45798976540'},
#  102: {'Name': 'Dhaval',
#   'DOB': (29, 'Feb', 1980),
#   'Phone No.': '+91-42398976540'}}

# %%
register_v2[101]
# Out:
# {'Name': 'Rubina', 'DOB': (1, 'Jan', 1980), 'Phone No.': '+91-45798976540'}

# %%
register_v3 = {
    101 : {
        "Name" : {
            "First Name" : "Rubina",
            "Last Name" : "Das"
        },
        "DOB" : (1, "Jan", 1980),
        "Phone No." : "+91-45798976540"
    },
    102 : {
        "Name" : {
            "First Name" : "Dhaval",
            "Last Name" : "Chouhan"
        },
        "DOB" : (29, "Feb", 1980),
        "Phone No." : "+91-42398976540"
    }
}

# %%
register_v3
# Out:
# {101: {'Name': {'First Name': 'Rubina', 'Last Name': 'Das'},
#   'DOB': (1, 'Jan', 1980),
#   'Phone No.': '+91-45798976540'},
#  102: {'Name': {'First Name': 'Dhaval', 'Last Name': 'Chouhan'},
#   'DOB': (29, 'Feb', 1980),
#   'Phone No.': '+91-42398976540'}}

# %%
get_DOB = register_v3.get(101).get("DOB")

# %%
type(get_DOB)
# Out:
# tuple

# %%
get_DOB
# Out:
# (1, 'Jan', 1980)

# %%
register_v3[101]["DOB"]
# Out:
# (1, 'Jan', 1980)

# %%
register_v3.get(101).get("Name").get("First Name")
# Out:
# 'Rubina'

# %%
a = 2

# %%
id(a)
# Out:
# 4331905592

# %%
a = 3

# %%
id(a)
# Out:
# 4331905624

# %%
a = [1, 2, 3, 4]

# %%
id(a[0])
# Out:
# 4331905560

# %%
a[0] = 5

# %%
id(a[0])
# Out:
# 4331905688

# %%
x = 10

def my_function():
  x = 5
  print(x)

my_function()
# Out:
# 5
