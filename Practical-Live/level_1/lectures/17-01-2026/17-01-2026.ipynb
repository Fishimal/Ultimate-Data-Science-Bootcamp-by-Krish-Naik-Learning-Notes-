# %% [markdown]
# # Python - 1
#
# ## Agenda:
# - Tools walkthrough
# - Environment setup
# - Notebook -> variables, data types and operators
# - Script and notebook execution

# %% [markdown]
# ### Variables
#
# To store something in a programming lanaguge we use variables

# %%
a = 12
# 12 will get stored into ram and a will hold the address of 12

# %%
a # this will print only because of notebook

# %%
print() # it is a function that shows the value of a varible or just output the value

# %%
print(a)

# %%
print(12)

# %% [markdown]
# ### Comments and multiline comments

# %%
# Comment starts with hash symbol --> #, also called as single line comment

# below is multi line comment or also used as doc string
"""
This is Ultimate data science batch v2.0.
In this class we are learning python variable
This is Ultimate data science batch v2.0.
In this class we are learning python variable
This is Ultimate data science batch v2.0.
In this class we are learning python variable
"""

'''
This is Ultimate data science batch v2.0.
In this class we are learning python variable
This is Ultimate data science batch v2.0.
In this class we are learning python variable
This is Ultimate data science batch v2.0.
In this class we are learning python variable
'''

# %% [markdown]
# ### Address of variable

# %%
a = 12
b = 12
print(id(a))
print(id(12))
print(id(b))

# %%
a
b

# %%
print(a)
b

# %%
a
print(b)

# %%
print(a)
print(b)

# %% [markdown]
# ### Data types

# %%
a = 10
type(a)

# %%
a = 10.0
type(a)

# %%
b = "data science"
type(b)

# %%
c = "d"
type(c) # type() -> identifies the data type of any variable

# %% [markdown]
# ### Naming convention
#
# - variable names can only contain letters, digits and underscore (_)
#     - bmi, person0, person_1, _person, id_1
# - it should not start with a digit
# - variable names are case sensitive : hello, Hello, heLlo
# - avoid using python keywords : type, print, id, if, else, for

# %% [markdown]
# ### Flow of python
#
# In python, execution happens from top to bottom and right to left
#
# in case of paranthesis, from inner brackets to outer

# %%
student_name = 'Rubina' # 1
# student_name = "Rubina"
print(student_name) # 2
value_1 = 100 # 3
print(500) # 4
value_2 = 200 # 5
print(value_1) # 6

# %% [markdown]
# ### Few more data types

# %%
# boolean or bool
# stores True or False

is_visible = False
is_visible = True

# %%
type(is_visible)

# %% [markdown]
# ### Type casting
#
# If we have int and we want to make it float, we use type casting

# %%
a = 1
type(a)

# %%
a = float(a)

# %%
a = 1
id(a)

# %%
a = 1.0
id(a)

# %%
type(a)

# %%
a = str(a)
print(a)
print(type(a))

# %%
print("Rubina")

# %%
pi = 3.14
pi_int = int(pi)
print(pi_int)
print(type(pi_int))

# %%
bool_1 = False
bool_int = int(bool_1)
print(bool_int)
print(type(bool_int))

# %% [markdown]
# ### Operators - 1

# %%
# arithmetic operators

# %%
2 + 2

# %%
a = 2
b = 2
c = a + b

# %%
a = 2
c = a + 2
print(c)

# %%
2 + "data science"

# %%
# ignore the code
for i in range(1,20):
    print(i)
    if i == 10:
        print("="*10)

# %%
2 + 2.0

# %%
100 - 2

# %%
# modulos operator

11 % 2

# %%
11 / 2 # division

# %%
11 // 2 # floor division

# %%
22/7
